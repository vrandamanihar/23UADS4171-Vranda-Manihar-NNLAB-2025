# %%
import tensorflow.compat.v1 as tf
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Disable TensorFlow 2 behavior
tf.disable_v2_behavior()

# Load MNIST dataset manually
from tensorflow.keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape(-1, 784).astype(np.float32) / 255.0
test_images = test_images.reshape(-1, 784).astype(np.float32) / 255.0
train_labels = np.eye(10)[train_labels]
test_labels = np.eye(10)[test_labels]

# Network Parameters
input_size = 784
output_size = 10
learning_rate = 0.01
epochs = 50
batch_size = 10

# Hyperparameters to tune
activation_functions = {'relu': tf.nn.relu, 'sigmoid': tf.nn.sigmoid, 'tanh': tf.nn.tanh}
hidden_layer_sizes = [256, 128, 64]

# Placeholder for results
results = []

for activation_name, activation_func in activation_functions.items():
    for hidden_layer_size in hidden_layer_sizes:
        print(f"Training with Activation: {activation_name}, Hidden Layer Size: {hidden_layer_size}")
        
        X = tf.placeholder(tf.float32, [None, input_size])
        Y = tf.placeholder(tf.float32, [None, output_size])
        
        weights = {
            'h1': tf.Variable(tf.random_normal([input_size, hidden_layer_size])),
            'out': tf.Variable(tf.random_normal([hidden_layer_size, output_size]))
        }
        biases = {
            'b1': tf.Variable(tf.random_normal([hidden_layer_size])),
            'out': tf.Variable(tf.random_normal([output_size]))
        }
        
        def neural_network(x):
            layer1 = activation_func(tf.add(tf.matmul(x, weights['h1']), biases['b1']))
            output_layer = tf.add(tf.matmul(layer1, weights['out']), biases['out'])
            return output_layer
        
        logits = neural_network(X)
        predictions = tf.nn.softmax(logits)
        
        loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=Y))
        optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss)
        
        correct_pred = tf.equal(tf.argmax(predictions, 1), tf.argmax(Y, 1))
        accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
        
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            start_time = time.time()
            train_losses = []
            train_accuracies = []
            
            for epoch in range(epochs):
                avg_loss = 0
                total_batches = train_images.shape[0] // batch_size
                
                for i in range(total_batches):
                    batch_x = train_images[i * batch_size:(i + 1) * batch_size]
                    batch_y = train_labels[i * batch_size:(i + 1) * batch_size]
                    _, c, acc = sess.run([optimizer, loss, accuracy], feed_dict={X: batch_x, Y: batch_y})
                    avg_loss += c
                
                avg_loss /= total_batches
                train_losses.append(avg_loss)
                train_accuracies.append(acc)
                print(f"Epoch {epoch+1}, Loss: {avg_loss:.4f}, Accuracy: {acc:.4f}")
            
            end_time = time.time()
            execution_time = end_time - start_time
            
            test_acc, preds = sess.run([accuracy, predictions], feed_dict={X: test_images, Y: test_labels})
            results.append((activation_name, hidden_layer_size, test_acc, execution_time))
            
            print(f"Final Test Accuracy: {test_acc:.4f}")
            print(f"Execution Time: {execution_time:.2f} seconds\n")
            
            # Plot loss and accuracy curves
            plt.figure(figsize=(12, 5))
            plt.subplot(1, 2, 1)
            plt.plot(range(epochs), train_losses, label='Loss')
            plt.xlabel('Epochs')
            plt.ylabel('Loss')
            plt.title(f'Loss Curve - {activation_name}, {hidden_layer_size}')
            plt.legend()
            
            plt.subplot(1, 2, 2)
            plt.plot(range(epochs), train_accuracies, label='Accuracy', color='green')
            plt.xlabel('Epochs')
            plt.ylabel('Accuracy')
            plt.title(f'Accuracy Curve - {activation_name}, {hidden_layer_size}')
            plt.legend()
            plt.show()
            
            y_true = np.argmax(test_labels, axis=1)
            y_pred = np.argmax(preds, axis=1)
            cm = confusion_matrix(y_true, y_pred)
            plt.figure(figsize=(8, 6))
            sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
            plt.xlabel('Predicted')
            plt.ylabel('Actual')
            plt.title(f'Confusion Matrix - {activation_name}, {hidden_layer_size}')
            plt.show()

print("\nHyperparameter Tuning Results:")
for activation, hl_size, acc, time_taken in results:
    print(f"Activation: {activation}, Hidden Layer: {hl_size}, Test Accuracy: {acc:.4f}, Time: {time_taken:.2f}s")
# Out:
# Training with Activation: relu, Hidden Layer Size: 256
# Epoch 1, Loss: 2.3371, Accuracy: 1.0000
# Epoch 2, Loss: 0.3588, Accuracy: 1.0000
# Epoch 3, Loss: 0.2880, Accuracy: 1.0000
# Epoch 4, Loss: 0.2634, Accuracy: 1.0000
# Epoch 5, Loss: 0.2437, Accuracy: 1.0000
# Epoch 6, Loss: 0.2288, Accuracy: 1.0000
# Epoch 7, Loss: 0.2172, Accuracy: 1.0000
# Epoch 8, Loss: 0.2147, Accuracy: 1.0000
# Epoch 9, Loss: 0.2081, Accuracy: 1.0000
# Epoch 10, Loss: 0.1874, Accuracy: 1.0000
# Epoch 11, Loss: 0.1893, Accuracy: 1.0000
# Epoch 12, Loss: 0.1888, Accuracy: 1.0000
# Epoch 13, Loss: 0.1749, Accuracy: 1.0000
# Epoch 14, Loss: 0.1684, Accuracy: 1.0000
# Epoch 15, Loss: 0.1798, Accuracy: 1.0000
# Epoch 16, Loss: 0.1887, Accuracy: 1.0000
# Epoch 17, Loss: 0.1600, Accuracy: 1.0000
# Epoch 18, Loss: 0.1625, Accuracy: 1.0000
# Epoch 19, Loss: 0.1558, Accuracy: 1.0000
# Epoch 20, Loss: 0.1761, Accuracy: 1.0000
# Epoch 21, Loss: 0.1591, Accuracy: 1.0000
# Epoch 22, Loss: 0.1668, Accuracy: 1.0000
# Epoch 23, Loss: 0.1660, Accuracy: 1.0000
# Epoch 24, Loss: 0.1678, Accuracy: 1.0000
# Epoch 25, Loss: 0.1529, Accuracy: 1.0000
# Epoch 26, Loss: 0.1555, Accuracy: 1.0000
# Epoch 27, Loss: 0.1474, Accuracy: 1.0000
# Epoch 28, Loss: 0.1512, Accuracy: 1.0000
# Epoch 29, Loss: 0.1479, Accuracy: 1.0000
# Epoch 30, Loss: 0.1556, Accuracy: 1.0000
# Epoch 31, Loss: 0.1371, Accuracy: 1.0000
# Epoch 32, Loss: 0.1497, Accuracy: 1.0000
# Epoch 33, Loss: 0.1359, Accuracy: 1.0000
# Epoch 34, Loss: 0.1415, Accuracy: 1.0000
# Epoch 35, Loss: 0.1423, Accuracy: 1.0000
# Epoch 36, Loss: 0.1301, Accuracy: 1.0000
# Epoch 37, Loss: 0.1400, Accuracy: 1.0000
# Epoch 38, Loss: 0.1311, Accuracy: 1.0000
# Epoch 39, Loss: 0.1337, Accuracy: 1.0000
# Epoch 40, Loss: 0.1553, Accuracy: 1.0000
# Epoch 41, Loss: 0.1061, Accuracy: 1.0000
# Epoch 42, Loss: 0.1261, Accuracy: 1.0000
# Epoch 43, Loss: 0.1330, Accuracy: 1.0000
# Epoch 44, Loss: 0.1354, Accuracy: 1.0000
# Epoch 45, Loss: 0.1239, Accuracy: 1.0000
# Epoch 46, Loss: 0.1302, Accuracy: 1.0000
# Epoch 47, Loss: 0.1207, Accuracy: 1.0000
# Epoch 48, Loss: 0.1349, Accuracy: 1.0000
# Epoch 49, Loss: 0.1155, Accuracy: 1.0000
# Epoch 7, Loss: 0.1313, Accuracy: 1.0000
# Epoch 8, Loss: 0.1250, Accuracy: 1.0000
# Epoch 9, Loss: 0.1157, Accuracy: 1.0000
# Epoch 10, Loss: 0.1132, Accuracy: 1.0000
# Epoch 11, Loss: 0.1079, Accuracy: 1.0000
# Epoch 12, Loss: 0.1043, Accuracy: 1.0000
# Epoch 13, Loss: 0.1060, Accuracy: 1.0000
# Epoch 14, Loss: 0.0979, Accuracy: 1.0000
# Epoch 15, Loss: 0.0975, Accuracy: 1.0000
# Epoch 16, Loss: 0.0964, Accuracy: 1.0000
# Epoch 17, Loss: 0.0952, Accuracy: 1.0000
# Epoch 18, Loss: 0.0858, Accuracy: 1.0000
# Epoch 19, Loss: 0.0887, Accuracy: 1.0000
# Epoch 20, Loss: 0.0848, Accuracy: 1.0000
# Epoch 21, Loss: 0.0864, Accuracy: 1.0000
# Epoch 22, Loss: 0.0814, Accuracy: 1.0000
# Epoch 23, Loss: 0.0832, Accuracy: 1.0000
# Epoch 24, Loss: 0.0796, Accuracy: 1.0000
# Epoch 25, Loss: 0.0764, Accuracy: 1.0000
# Epoch 26, Loss: 0.0759, Accuracy: 1.0000
# Epoch 27, Loss: 0.0742, Accuracy: 1.0000
# Epoch 28, Loss: 0.0701, Accuracy: 1.0000
# Epoch 29, Loss: 0.0738, Accuracy: 1.0000
# Epoch 30, Loss: 0.0732, Accuracy: 1.0000
# Epoch 31, Loss: 0.0685, Accuracy: 1.0000
# Epoch 32, Loss: 0.0698, Accuracy: 1.0000
# Epoch 33, Loss: 0.0694, Accuracy: 1.0000
# Epoch 34, Loss: 0.0646, Accuracy: 1.0000
# Epoch 35, Loss: 0.0649, Accuracy: 1.0000
# Epoch 36, Loss: 0.0637, Accuracy: 1.0000
# Epoch 37, Loss: 0.0656, Accuracy: 1.0000
# Epoch 38, Loss: 0.0688, Accuracy: 1.0000
# Epoch 39, Loss: 0.0642, Accuracy: 1.0000
# Epoch 40, Loss: 0.0655, Accuracy: 1.0000
# Epoch 41, Loss: 0.0634, Accuracy: 1.0000
# Epoch 42, Loss: 0.0603, Accuracy: 1.0000
# Epoch 43, Loss: 0.0612, Accuracy: 1.0000
# Epoch 44, Loss: 0.0591, Accuracy: 1.0000
# Epoch 45, Loss: 0.0567, Accuracy: 1.0000
# Epoch 46, Loss: 0.0573, Accuracy: 1.0000
# Epoch 47, Loss: 0.0546, Accuracy: 1.0000
# Epoch 48, Loss: 0.0541, Accuracy: 1.0000
# Epoch 49, Loss: 0.0528, Accuracy: 1.0000
# Epoch 50, Loss: 0.0548, Accuracy: 1.0000
# Final Test Accuracy: 0.9665
# Execution Time: 698.17 seconds
# Training with Activation: tanh, Hidden Layer Size: 256
# Epoch 1, Loss: 1.0294, Accuracy: 1.0000
# Epoch 2, Loss: 0.5955, Accuracy: 1.0000
# Epoch 3, Loss: 0.5459, Accuracy: 1.0000
# Epoch 4, Loss: 0.5059, Accuracy: 1.0000
# Epoch 5, Loss: 0.5074, Accuracy: 1.0000
# Epoch 6, Loss: 0.4878, Accuracy: 1.0000
# Epoch 7, Loss: 0.4643, Accuracy: 1.0000
# Epoch 8, Loss: 0.4246, Accuracy: 1.0000
# Epoch 9, Loss: 0.4289, Accuracy: 0.9000
# Epoch 10, Loss: 0.4326, Accuracy: 1.0000
# Epoch 11, Loss: 0.4008, Accuracy: 1.0000
# Epoch 12, Loss: 0.4031, Accuracy: 1.0000
# Epoch 13, Loss: 0.4104, Accuracy: 1.0000
# Epoch 14, Loss: 0.4099, Accuracy: 1.0000
# Epoch 15, Loss: 0.3926, Accuracy: 1.0000
# Epoch 16, Loss: 0.3960, Accuracy: 1.0000
# Epoch 17, Loss: 0.4032, Accuracy: 1.0000
# Epoch 18, Loss: 0.4042, Accuracy: 1.0000
# Epoch 19, Loss: 0.3915, Accuracy: 1.0000
# Epoch 20, Loss: 0.3741, Accuracy: 1.0000
# Epoch 21, Loss: 0.3790, Accuracy: 1.0000
# Epoch 22, Loss: 0.3810, Accuracy: 1.0000
# Epoch 23, Loss: 0.3465, Accuracy: 1.0000
# Epoch 24, Loss: 0.3567, Accuracy: 1.0000
# Epoch 25, Loss: 0.3659, Accuracy: 1.0000
# Epoch 26, Loss: 0.3729, Accuracy: 1.0000
# Epoch 27, Loss: 0.3637, Accuracy: 1.0000
# Epoch 28, Loss: 0.3565, Accuracy: 1.0000
# Epoch 29, Loss: 0.3617, Accuracy: 1.0000
# Epoch 30, Loss: 0.3513, Accuracy: 1.0000
# Epoch 31, Loss: 0.3504, Accuracy: 1.0000
# Epoch 32, Loss: 0.3471, Accuracy: 1.0000
# Epoch 33, Loss: 0.3285, Accuracy: 1.0000
# Epoch 34, Loss: 0.3351, Accuracy: 1.0000
# Epoch 35, Loss: 0.3324, Accuracy: 1.0000
# Epoch 36, Loss: 0.3274, Accuracy: 1.0000
# Epoch 37, Loss: 0.3254, Accuracy: 1.0000
# Epoch 38, Loss: 0.3419, Accuracy: 1.0000
# Epoch 39, Loss: 0.3426, Accuracy: 1.0000
# Epoch 40, Loss: 0.3390, Accuracy: 1.0000
# Epoch 41, Loss: 0.3213, Accuracy: 1.0000
# Epoch 42, Loss: 0.3186, Accuracy: 1.0000
# Epoch 43, Loss: 0.3240, Accuracy: 1.0000
# Epoch 44, Loss: 0.3086, Accuracy: 1.0000
# Epoch 45, Loss: 0.3232, Accuracy: 1.0000
# Epoch 46, Loss: 0.3316, Accuracy: 1.0000
# Epoch 47, Loss: 0.3085, Accuracy: 1.0000
# Epoch 48, Loss: 0.3024, Accuracy: 1.0000
# Epoch 49, Loss: 0.2970, Accuracy: 1.0000
# Epoch 50, Loss: 0.2924, Accuracy: 1.0000
# Final Test Accuracy: 0.9376
# Execution Time: 594.03 seconds
# Training with Activation: tanh, Hidden Layer Size: 128
# Epoch 1, Loss: 0.6948, Accuracy: 1.0000
# Epoch 2, Loss: 0.3980, Accuracy: 1.0000
# Epoch 3, Loss: 0.3431, Accuracy: 1.0000
# Epoch 4, Loss: 0.3225, Accuracy: 1.0000
# Epoch 5, Loss: 0.3031, Accuracy: 1.0000
# Epoch 6, Loss: 0.2931, Accuracy: 1.0000
# Epoch 7, Loss: 0.2768, Accuracy: 1.0000
# Epoch 8, Loss: 0.2640, Accuracy: 1.0000
# Epoch 9, Loss: 0.2734, Accuracy: 1.0000
# Epoch 10, Loss: 0.2645, Accuracy: 1.0000
# Epoch 11, Loss: 0.2533, Accuracy: 1.0000
# Epoch 12, Loss: 0.2546, Accuracy: 1.0000
# Epoch 13, Loss: 0.2363, Accuracy: 1.0000
# Epoch 14, Loss: 0.2513, Accuracy: 0.9000
# Epoch 15, Loss: 0.2366, Accuracy: 1.0000
# Epoch 16, Loss: 0.2370, Accuracy: 1.0000
# Epoch 17, Loss: 0.2202, Accuracy: 1.0000
# Epoch 18, Loss: 0.2266, Accuracy: 1.0000
# Epoch 19, Loss: 0.2330, Accuracy: 1.0000
# Epoch 20, Loss: 0.2149, Accuracy: 1.0000
# Epoch 21, Loss: 0.2133, Accuracy: 1.0000
# Epoch 22, Loss: 0.2102, Accuracy: 1.0000
# Epoch 23, Loss: 0.2133, Accuracy: 1.0000
# Epoch 24, Loss: 0.2043, Accuracy: 1.0000
# Epoch 25, Loss: 0.2151, Accuracy: 1.0000
# Epoch 26, Loss: 0.2107, Accuracy: 1.0000
# Epoch 27, Loss: 0.2050, Accuracy: 1.0000
# Epoch 28, Loss: 0.2089, Accuracy: 1.0000
# Epoch 29, Loss: 0.1976, Accuracy: 1.0000
# Epoch 30, Loss: 0.2005, Accuracy: 1.0000
# Epoch 31, Loss: 0.2025, Accuracy: 1.0000
# Epoch 32, Loss: 0.1947, Accuracy: 0.9000
# Epoch 33, Loss: 0.1909, Accuracy: 1.0000
# Epoch 34, Loss: 0.1843, Accuracy: 1.0000
# Epoch 35, Loss: 0.1939, Accuracy: 1.0000
# Epoch 36, Loss: 0.1865, Accuracy: 1.0000
# Epoch 37, Loss: 0.1929, Accuracy: 1.0000
# Epoch 38, Loss: 0.1921, Accuracy: 1.0000
# Epoch 39, Loss: 0.1921, Accuracy: 1.0000
# Epoch 40, Loss: 0.1816, Accuracy: 1.0000
# Epoch 41, Loss: 0.1907, Accuracy: 1.0000
# Epoch 42, Loss: 0.1833, Accuracy: 1.0000
# Epoch 43, Loss: 0.1847, Accuracy: 1.0000
# Epoch 44, Loss: 0.1870, Accuracy: 1.0000
# Epoch 45, Loss: 0.1885, Accuracy: 1.0000
# Epoch 46, Loss: 0.1845, Accuracy: 1.0000
# Epoch 47, Loss: 0.1703, Accuracy: 1.0000
# Epoch 48, Loss: 0.1722, Accuracy: 1.0000
# Epoch 49, Loss: 0.1870, Accuracy: 1.0000
# Epoch 50, Loss: 0.1727, Accuracy: 1.0000
# Final Test Accuracy: 0.9627
# Execution Time: 407.81 seconds
# Training with Activation: tanh, Hidden Layer Size: 64
# Epoch 1, Loss: 0.6142, Accuracy: 1.0000
# Epoch 2, Loss: 0.3282, Accuracy: 1.0000
# Epoch 3, Loss: 0.2751, Accuracy: 1.0000
# Epoch 4, Loss: 0.2530, Accuracy: 1.0000
# Epoch 5, Loss: 0.2366, Accuracy: 1.0000
# Epoch 6, Loss: 0.2338, Accuracy: 1.0000
# Epoch 7, Loss: 0.2191, Accuracy: 1.0000
# Epoch 8, Loss: 0.2105, Accuracy: 1.0000
# Epoch 9, Loss: 0.2012, Accuracy: 1.0000
# Epoch 10, Loss: 0.2039, Accuracy: 1.0000
# Epoch 11, Loss: 0.1916, Accuracy: 1.0000
# Epoch 12, Loss: 0.1885, Accuracy: 1.0000
# Epoch 13, Loss: 0.1801, Accuracy: 1.0000
# Epoch 14, Loss: 0.1744, Accuracy: 1.0000
# Epoch 15, Loss: 0.1838, Accuracy: 1.0000
# Epoch 16, Loss: 0.1716, Accuracy: 1.0000
# Epoch 17, Loss: 0.1722, Accuracy: 1.0000
# Epoch 18, Loss: 0.1798, Accuracy: 1.0000
# Epoch 19, Loss: 0.1629, Accuracy: 1.0000
# Epoch 20, Loss: 0.1691, Accuracy: 1.0000
# Epoch 21, Loss: 0.1655, Accuracy: 1.0000
# Epoch 22, Loss: 0.1580, Accuracy: 1.0000
# Epoch 23, Loss: 0.1492, Accuracy: 1.0000
# Epoch 24, Loss: 0.1509, Accuracy: 1.0000
# Epoch 25, Loss: 0.1485, Accuracy: 1.0000
# Epoch 26, Loss: 0.1536, Accuracy: 1.0000
# Epoch 27, Loss: 0.1526, Accuracy: 1.0000
# Epoch 28, Loss: 0.1548, Accuracy: 1.0000
# Epoch 29, Loss: 0.1452, Accuracy: 1.0000
# Epoch 30, Loss: 0.1487, Accuracy: 1.0000
# Epoch 31, Loss: 0.1429, Accuracy: 1.0000
# Epoch 32, Loss: 0.1418, Accuracy: 1.0000
# Epoch 33, Loss: 0.1474, Accuracy: 1.0000
# Epoch 34, Loss: 0.1326, Accuracy: 1.0000
# Epoch 35, Loss: 0.1442, Accuracy: 1.0000
# Epoch 36, Loss: 0.1387, Accuracy: 1.0000
# Epoch 37, Loss: 0.1441, Accuracy: 1.0000
# Epoch 38, Loss: 0.1329, Accuracy: 1.0000
# Epoch 39, Loss: 0.1293, Accuracy: 1.0000
# Epoch 40, Loss: 0.1324, Accuracy: 1.0000
# Epoch 41, Loss: 0.1321, Accuracy: 1.0000
# Epoch 42, Loss: 0.1301, Accuracy: 1.0000
# Epoch 43, Loss: 0.1282, Accuracy: 1.0000
# Epoch 44, Loss: 0.1264, Accuracy: 1.0000
# Epoch 45, Loss: 0.1291, Accuracy: 1.0000
# Epoch 46, Loss: 0.1383, Accuracy: 1.0000
# Epoch 47, Loss: 0.1274, Accuracy: 1.0000
# Epoch 48, Loss: 0.1279, Accuracy: 1.0000
# Epoch 49, Loss: 0.1271, Accuracy: 1.0000
# Epoch 50, Loss: 0.1279, Accuracy: 1.0000
# Final Test Accuracy: 0.9494
# Execution Time: 289.31 seconds
# Hyperparameter Tuning Results:
# Activation: relu, Hidden Layer: 256, Test Accuracy: 0.9619, Time: 562.58s
# Activation: relu, Hidden Layer: 128, Test Accuracy: 0.9544, Time: 903.11s
# Activation: relu, Hidden Layer: 64, Test Accuracy: 0.9499, Time: 541.66s
# Activation: sigmoid, Hidden Layer: 256, Test Accuracy: 0.9687, Time: 599.20s
# Activation: sigmoid, Hidden Layer: 128, Test Accuracy: 0.9634, Time: 578.28s
# Activation: sigmoid, Hidden Layer: 64, Test Accuracy: 0.9665, Time: 698.17s
# Activation: tanh, Hidden Layer: 256, Test Accuracy: 0.9376, Time: 594.03s
# Activation: tanh, Hidden Layer: 128, Test Accuracy: 0.9627, Time: 407.81s
# Activation: tanh, Hidden Layer: 64, Test Accuracy: 0.9494, Time: 289.31s
